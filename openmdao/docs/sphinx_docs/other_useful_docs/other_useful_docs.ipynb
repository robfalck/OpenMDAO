# %% [markdown]
# # Other Useful Docs
#
# This section contains documentation for command-line tools, API translation guides, developer documentation, and more.
#
# ## Command Line Tools
#
# - [OpenMDAO Command Line Tool](om_command.ipynb)
# - [Citing OpenMDAO](../other/citing.ipynb)
#
# ## Building OpenMDAO-Based Tools
#
# - [Building a Tool on Top of OpenMDAO](building_a_tool/building_a_tool.md)
# - [Repository Structure](building_a_tool/repository_structure.ipynb)
# - [Release Process](building_a_tool/release_process.ipynb)
#
# ## API Guides
#
# - [Auto-IVC API Translation Guide](auto_ivc_api_translation.ipynb)
# - [API Translation Guide](api_translation.ipynb)
# - [Environment Variables](environment_vars.ipynb)
# - [File Wrapping Utility](file_wrap.ipynb)
#
# ## Source Documentation
#
# - [Source Code Documentation](../_srcdocs/index.ipynb)
#
# ## Developer Documentation
#
# - [Developer Documentation](developer_docs/developer_docs.ipynb)
# - [Signing Commits](developer_docs/signing_commits.ipynb)
# - [Unit Testing](developer_docs/unit_testing.ipynb)
# - [CI Testing](developer_docs/ci_testing.ipynb)
# - [Building the Documentation](developer_docs/doc_build.ipynb)
# - [Documentation Style Guide](developer_docs/doc_style_guide.ipynb)
# - [Sphinx Decorators](developer_docs/sphinx_decorators.ipynb)
# - [Writing Plugins](developer_docs/writing_plugins.ipynb)
